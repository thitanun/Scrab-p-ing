# %%
import re
import json
from urllib.parse import urlparse
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import pandas as pd

# %%
class testThaiger:

    def __init__(self):
        self.data = {}
        self.data['web'] = {}

    
    def remove_unuse_tag(self, bs : BeautifulSoup):
        unuse_tag = ['script', 'style ', 'noscript', 'head', 'footer', 'iframe']
        for tag in unuse_tag:
            for s in bs.select(tag):
                if s != None:
                    s.extract()
        return bs

    def clean_html(self, html : str):
        clean = re.compile('<.*?>')
        clean_text = re.sub(clean, '', html)
        for char in ['\n', '\t', '\r']:
            clean_text = clean_text.replace(char, '')
        clean_text = re.sub(' +', ' ', clean_text)
        return clean_text

    def data_in_link(self, session, url):
        self.list_url = []
        self.list_title = []
        self.list_content = []

        with session.get(url) as response:
            if not response.ok:
                return
            print('test url', url)
            
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs inlink', bs)
            
            self.data['web'][url] = {}
            self.data['web'][url]['title'] = bs.find('h1').text

            self.content = ''
            section = bs.find('div', {'id' : 'mvp-content-main'})
            for p in section.find_all('p'):
                self.content += f'{self.clean_html(p.text)} ' #p.text
            self.data['web'][url]['content'] = self.content
            # print('test content inlink', self.content)



    def data_domain(self, session, url):
        with session.get(url) as response:
            if not response.ok:
                return
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs domain', bs)

            news_link = []
            for li in bs.find_all('li', {'class' : 'mvp-blog-story-wrap left relative infinite-post'}):
                a = li.find('a')
                news_link.append(a.attrs['href'])
            # print('test news_link domain', news_link)

            n = len(news_link)
            # print('test n news_link domain', n)
            with ThreadPoolExecutor(max_workers=n) as executor:
                with requests.Session() as session:
                    executor.map(self.data_in_link, [session]*n, news_link)
                    executor.shutdown(wait=True)


    def scrap(self):
        pages_list = [f'https://thethaiger.com/th/entertainment/korean-entertainment/page/{i}' for i in range(1, 11)]
        n = len(pages_list)
        print('test page', pages_list)
        with ThreadPoolExecutor(max_workers=n) as executor:
            with requests.Session() as session:
                executor.map(self.data_domain, [session]*n, pages_list)
                executor.shutdown(wait=True)


    def save_to_json(self):
        with open(f'Thaiger.json', 'w', encoding="UTF-8") as file:
            datafile = json.dumps(self.data, indent=4) 
            file.write(datafile)


    # def dataframe_web(self):

    #     data_web = [[self.list_url
    #                     ]]

    #     web_frame = pd.DataFrame(data=data_web,
    #                         columns=['link'])
    #     return web_frame

    # def twitter_to_xlsx(self, data):
    #     data.to_excel("hey_test.xlsx", engine="openpyxl", index=False)

# %%
data = testThaiger()
data

# %%
data.scrap()
# Out:
# test page ['https://thethaiger.com/th/entertainment/korean-entertainment/page/1', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/2', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/3', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/4', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/5', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/6', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/7', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/8', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/9', 'https://thethaiger.com/th/entertainment/korean-entertainment/page/10']
# test url https://thethaiger.com/th/news/557515/
# test url https://thethaiger.com/th/news/510863/
# test url https://thethaiger.com/th/news/510060/
# test url test urlhttps://thethaiger.com/th/news/506146/
#  https://thethaiger.com/th/news/509822/
# test url https://thethaiger.com/th/news/506164/
# test url https://thethaiger.com/th/news/506514/
# test url https://thethaiger.com/th/news/509957/
# test url https://thethaiger.com/th/news/510721/
# test url https://thethaiger.com/th/news/557043/
# test url https://thethaiger.com/th/news/552381/
# test url https://thethaiger.com/th/news/553112/
# test url https://thethaiger.com/th/news/557332/
# test url https://thethaiger.com/th/news/528645/
# test url https://thethaiger.com/th/news/507982/
# test url https://thethaiger.com/th/news/528364/
# test url https://thethaiger.com/th/news/553796/
# test url https://thethaiger.com/th/news/507338/
# test url https://thethaiger.com/th/news/533106/
# test url https://thethaiger.com/th/news/552631/
# test url https://thethaiger.com/th/news/509774/
# test url https://thethaiger.com/th/news/556136/
# test url https://thethaiger.com/th/news/538418/
# test url test url https://thethaiger.com/th/news/509732/
# https://thethaiger.com/th/news/528612/test url https://thethaiger.com/th/news/550179/
#
# test url https://thethaiger.com/th/news/529052/
# test url https://thethaiger.com/th/news/507594/
# test url https://thethaiger.com/th/news/555517/
# test url test url https://thethaiger.com/th/news/503424/https://thethaiger.com/th/news/556417/
#
# test urltest url  https://thethaiger.com/th/news/505935/https://thethaiger.com/th/news/528497/
#
# test url https://thethaiger.com/th/news/537147/
# test url https://thethaiger.com/th/news/508081/
# test url test url https://thethaiger.com/th/news/503644/https://thethaiger.com/th/news/507826/
# test url https://thethaiger.com/th/news/505584/
# test url https://thethaiger.com/th/news/548503/
#
# test url https://thethaiger.com/th/news/555165/
# test url https://thethaiger.com/th/news/552148/
# test url https://thethaiger.com/th/news/554107/
# test urltest url https://thethaiger.com/th/news/551926/
#  https://thethaiger.com/th/news/509482/
# test url https://thethaiger.com/th/news/505911/
# test url https://thethaiger.com/th/news/525297/
# test url https://thethaiger.com/th/news/537102/
# test url https://thethaiger.com/th/news/506623/
# test url https://thethaiger.com/th/news/556088/
# test url https://thethaiger.com/th/news/551160/
# test url https://thethaiger.com/th/news/535698/test url https://thethaiger.com/th/news/535888/
#
# test url https://thethaiger.com/th/news/555201/
# test url https://thethaiger.com/th/news/509070/
# test url https://thethaiger.com/th/news/527739/
# test url https://thethaiger.com/th/news/522314/
# test urltest url https://thethaiger.com/th/news/530830/
#  https://thethaiger.com/th/news/560136/
# test url https://thethaiger.com/th/news/554339/
# test urltest url  https://thethaiger.com/th/news/532561/
# test url https://thethaiger.com/th/news/555622/
# test urlhttps://thethaiger.com/th/news/554264/ https://thethaiger.com/th/news/556164/
# test url https://thethaiger.com/th/news/535803/
# test url https://thethaiger.com/th/news/509716/
# test urltest url https://thethaiger.com/th/news/508424/
#  https://thethaiger.com/th/news/551059/
#
# test url https://thethaiger.com/th/news/555906/
# test url https://thethaiger.com/th/news/524916/
# test urltest url  https://thethaiger.com/th/news/555069/
# https://thethaiger.com/th/news/550106/
# test url https://thethaiger.com/th/news/551184/
# test url https://thethaiger.com/th/news/507186/
# test url https://thethaiger.com/th/news/550187/
# test url https://thethaiger.com/th/news/524419/
# test url https://thethaiger.com/th/news/550130/
# test url https://thethaiger.com/th/news/528849/test url
#  https://thethaiger.com/th/news/513729/
# test url test url https://thethaiger.com/th/news/551034/https://thethaiger.com/th/news/514727/
#
# test url https://thethaiger.com/th/news/504705/
# test url https://thethaiger.com/th/news/505784/
# test url https://thethaiger.com/th/news/505467/
# test url https://thethaiger.com/th/news/528359/
# test url https://thethaiger.com/th/news/502939/
# test url https://thethaiger.com/th/news/550014/
# test url https://thethaiger.com/th/news/526001/
# test url https://thethaiger.com/th/news/558472/
# test url https://thethaiger.com/th/news/504484/
# test url https://thethaiger.com/th/news/504944/
# test url https://thethaiger.com/th/news/553762/
# test url https://thethaiger.com/th/news/515337/
# test url test urlhttps://thethaiger.com/th/news/545169/ https://thethaiger.com/th/news/532394/
#
# test url https://thethaiger.com/th/news/506564/
# test url https://thethaiger.com/th/news/522915/
# test url https://thethaiger.com/th/news/507803/
# test url https://thethaiger.com/th/news/525654/
# test url https://thethaiger.com/th/news/510965/
# test url https://thethaiger.com/th/news/502575/
# test url https://thethaiger.com/th/news/515605/
# test urltest url  https://thethaiger.com/th/news/525880/
# https://thethaiger.com/th/news/535774/
# test urltest url https://thethaiger.com/th/news/534094/
#  https://thethaiger.com/th/news/515135/
# test url https://thethaiger.com/th/news/532221/
# test url https://thethaiger.com/th/news/524754/
# test urltest url  https://thethaiger.com/th/news/538346/https://thethaiger.com/th/news/518545/
# test url
#  https://thethaiger.com/th/news/524089/
# test url https://thethaiger.com/th/news/559919/
# test urltest url https://thethaiger.com/th/news/514399/
# test url https://thethaiger.com/th/news/558302/
# test url https://thethaiger.com/th/news/512751/
# test url https://thethaiger.com/th/news/503859/
# test url https://thethaiger.com/th/news/545610/
# test url https://thethaiger.com/th/news/523188/
#  https://thethaiger.com/th/news/533704/
# test url https://thethaiger.com/th/news/502899/test url https://thethaiger.com/th/news/502753/test url
#
# https://thethaiger.com/th/news/549135/test url
# https://thethaiger.com/th/news/548052/
# test urltest url https://thethaiger.com/th/news/547569/
# test url https://thethaiger.com/th/news/532382/
# test url https://thethaiger.com/th/news/514198/test urltest url  https://thethaiger.com/th/news/558817/
# test url https://thethaiger.com/th/news/553263/
#
# https://thethaiger.com/th/news/522815/
#  https://thethaiger.com/th/news/548261/
# test url https://thethaiger.com/th/news/558782/
# test url test url https://thethaiger.com/th/news/553520/
# https://thethaiger.com/th/news/523802/test url https://thethaiger.com/th/news/559234/
# test url
# test url https://thethaiger.com/th/news/531556/
#  test url https://thethaiger.com/th/news/510888/
# https://thethaiger.com/th/news/546366/
# test url https://thethaiger.com/th/news/503083/
# test url https://thethaiger.com/th/news/558884/
# test url https://thethaiger.com/th/news/559830/
# test url test urlhttps://thethaiger.com/th/news/531051/
#  https://thethaiger.com/th/news/511159/
# test url https://thethaiger.com/th/news/532538/
# test urltest url https://thethaiger.com/th/news/511792/
#  https://thethaiger.com/th/news/520556/
# test url https://thethaiger.com/th/news/545098/
# test url https://thethaiger.com/th/news/547980/
# test url https://thethaiger.com/th/news/517676/
# test urltest url https://thethaiger.com/th/news/513068/
#  https://thethaiger.com/th/news/511927/
# test urltest url  https://thethaiger.com/th/news/522952/
# https://thethaiger.com/th/news/559360/
# test url https://thethaiger.com/th/news/548176/
# test url https://thethaiger.com/th/news/546624/
# test url https://thethaiger.com/th/news/522157/
# test url https://thethaiger.com/th/news/531027/
# test url https://thethaiger.com/th/news/520472/
# test url https://thethaiger.com/th/news/560025/test url
#  https://thethaiger.com/th/news/545532/
# test url https://thethaiger.com/th/news/543250/
# test url https://thethaiger.com/th/news/545979/
# test urltest url https://thethaiger.com/th/news/539549/
#  https://thethaiger.com/th/news/512882/
# test urltest url https://thethaiger.com/th/news/522967/
#  test url https://thethaiger.com/th/news/511800/
# https://thethaiger.com/th/news/547418/test url https://thethaiger.com/th/news/531887/
# test url
#  https://thethaiger.com/th/news/518921/
# test url https://thethaiger.com/th/news/517218/
# test url test url https://thethaiger.com/th/news/540784/
# test url https://thethaiger.com/th/news/539475/
# https://thethaiger.com/th/news/512770/test url https://thethaiger.com/th/news/518899/test url
#
# https://thethaiger.com/th/news/539390/
# test url https://thethaiger.com/th/news/517523/
# test url https://thethaiger.com/th/news/513707/
# test url https://thethaiger.com/th/news/558799/
# test url https://thethaiger.com/th/news/518733/test url https://thethaiger.com/th/news/546536/
# test url https://thethaiger.com/th/news/516408/
# test url https://thethaiger.com/th/news/539212/
# test url
# https://thethaiger.com/th/news/517912/
# test url https://thethaiger.com/th/news/512447/
# test url https://thethaiger.com/th/news/516545/
# test url https://thethaiger.com/th/news/558580/
# test url https://thethaiger.com/th/news/538744/
# test url https://thethaiger.com/th/news/513085/
# test url https://thethaiger.com/th/news/520972/
# test url https://thethaiger.com/th/news/540163/
# test url https://thethaiger.com/th/news/516498/
# test url https://thethaiger.com/th/news/545860/
# test url https://thethaiger.com/th/news/503451/
# test url https://thethaiger.com/th/news/518006/
# test url https://thethaiger.com/th/news/539172/

# %%
# data.dataframe_web()

# %%
data.save_to_json()

# %%
# hey = data.dataframe_web()
# data.twitter_to_xlsx(hey)
