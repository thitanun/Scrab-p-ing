# %%
import re
import json
from urllib.parse import urlparse
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import pandas as pd

# %%
class testSudsapda:

    def __init__(self):
        self.data = {}
        self.data['web'] = {}

    
    def remove_unuse_tag(self, bs : BeautifulSoup):
        unuse_tag = ['script', 'style ', 'noscript', 'head', 'footer', 'iframe']
        for tag in unuse_tag:
            for s in bs.select(tag):
                if s != None:
                    s.extract()
        return bs

    def clean_html(self, html : str):
        clean = re.compile('<.*?>')
        clean_text = re.sub(clean, '', html)
        for char in ['\n', '\t', '\r']:
            clean_text = clean_text.replace(char, '')
        clean_text = re.sub(' +', ' ', clean_text)
        return clean_text

    def data_in_link(self, session, url):
        self.list_url = []
        self.list_title = []
        self.list_content = []

        with session.get(url) as response:
            if not response.ok:
                return
            print('test url', url)
            
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs inlink', bs)
            
            self.data['web'][url] = {}
            self.data['web'][url]['title'] = bs.find('h1').text

            self.content = ''
            section = bs.find('div', {'id' : 'content-inner'})
            # print('test sec', section)
            for p in section.find_all('p'):
                # print('test p', p)
                self.content += f'{self.clean_html(p.text)} ' #p.text
            self.data['web'][url]['content'] = self.content
            # print('test content inlink', self.content)



    def data_domain(self, session, url):
        with session.get(url) as response:
            # print('check re', response)
            if not response.ok:
                return
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs domain', bs)

            news_link = []
            for div in bs.find_all('div', {'class' : 'title-block col s7 l6'}):
                a = div.find('a')
                news_link.append(a.attrs['href'])
            # print('test news_link domain', news_link)

            n = len(news_link)
            # print('test n news_link domain', n)
            with ThreadPoolExecutor(max_workers=n) as executor:
                with requests.Session() as session:
                    executor.map(self.data_in_link, [session]*n, news_link)
                    executor.shutdown(wait=True)


    def scrap(self):
        pages_list = [f'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/{i}' for i in range(1, 11)]
        n = len(pages_list)
        print('test page' , pages_list)
        with ThreadPoolExecutor(max_workers=n) as executor:
            with requests.Session() as session:
                executor.map(self.data_domain, [session]*n, pages_list)
                executor.shutdown(wait=True)


    def save_to_json(self):
        with open(f'Sudsapda.json', 'w', encoding="UTF-8") as file:
            datafile = json.dumps(self.data, indent=4) 
            file.write(datafile)


    # def dataframe_web(self):

    #     data_web = [[self.list_url
    #                     ]]

    #     web_frame = pd.DataFrame(data=data_web,
    #                         columns=['link'])
    #     return web_frame

    # def twitter_to_xlsx(self, data):
    #     data.to_excel("hey_test.xlsx", engine="openpyxl", index=False)

# %%
data = testSudsapda()
data

# %%
data.scrap()
# Out:
# test page ['https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/1', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/2', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/3', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/4', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/5', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/6', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/7', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/8', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/9', 'https://sudsapda.com/tag/%E0%B8%9A%E0%B8%B1%E0%B8%99%E0%B9%80%E0%B8%97%E0%B8%B4%E0%B8%87%E0%B9%80%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%B5/page/10']
# test url https://sudsapda.com/top-lists/235946.html
# test url https://sudsapda.com/men/201269.html
# test url https://sudsapda.com/men/209779.html
# test url https://sudsapda.com/men/149524.html
# test url https://sudsapda.com/men/146322.html
# test url https://sudsapda.com/top-lists/147070.html
# test urltest url https://sudsapda.com/top-lists/142493.html
#  https://sudsapda.com/top-lists/146829.htmltest url
# test url https://sudsapda.com/film/169493.html
# test url https://sudsapda.com/men/129470.html
#  https://sudsapda.com/top-lists/128591.html
# test url https://sudsapda.com/top-lists/166833.html
# test url test url https://sudsapda.com/men/135670.html
# test url https://sudsapda.com/top-lists/134134.html
# test url https://sudsapda.com/top-lists/191423.html
# https://sudsapda.com/top-lists/125540.html
# test url https://sudsapda.com/top-lists/141414.html
# test url https://sudsapda.com/top-lists/132059.html
# test url test url https://sudsapda.com/men/180654.html
# https://sudsapda.com/top-lists/134948.htmltest url https://sudsapda.com/men/146761.html
#
# test url https://sudsapda.com/top-lists/129311.html
# test url test urlhttps://sudsapda.com/men/141816.html
#  https://sudsapda.com/top-lists/144678.html
# test urltest url  https://sudsapda.com/top-lists/165455.htmltest urlhttps://sudsapda.com/men/134503.html
#  https://sudsapda.com/top-lists/194933.html
# test url https://sudsapda.com/men/136612.html
# test url
#  https://sudsapda.com/top-lists/171549.html
# test url https://sudsapda.com/men/128808.html
# test url https://sudsapda.com/top-lists/127651.html
# test url https://sudsapda.com/men/146124.html
# test url https://sudsapda.com/top-lists/161999.html
# test url https://sudsapda.com/men/146661.html
# test url https://sudsapda.com/top-lists/132632.html
# test urltest url  https://sudsapda.com/top-lists/121269.htmlhttps://sudsapda.com/top-lists/127474.html
#
# test url https://sudsapda.com/men/129645.html
# test url https://sudsapda.com/men/134766.html
# test urltest url https://sudsapda.com/men/131323.html
# https://sudsapda.com/film/145644.html
# test urltest url https://sudsapda.com/top-lists/142056.html
#  https://sudsapda.com/top-lists/125941.html
# test url https://sudsapda.com/top-lists/118424.html
# test url https://sudsapda.com/top-lists/193623.html
# test url https://sudsapda.com/men/163063.html
# test urltest url https://sudsapda.com/men/127822.html
# test url https://sudsapda.com/men/130101.html
# test url https://sudsapda.com/men/145493.html
#  https://sudsapda.com/men/135036.html
# test url https://sudsapda.com/top-lists/139093.html
# test url https://sudsapda.com/men/147777.htmltest url
#  https://sudsapda.com/top-lists/141545.html
# test url https://sudsapda.com/film/140161.html
# test url https://sudsapda.com/top-lists/139647.html
# test urltest url test url test url https://sudsapda.com/top-lists/124590.html
# https://sudsapda.com/men/193389.html
#  https://sudsapda.com/top-lists/143899.html
# test url https://sudsapda.com/top-lists/144251.htmltest url https://sudsapda.com/top-lists/134374.html
#
# https://sudsapda.com/top-lists/126286.htmltest url https://sudsapda.com/top-lists/175773.html
#
# test urltest url  https://sudsapda.com/top-lists/120435.htmltest url https://sudsapda.com/men/145966.html
#
# https://sudsapda.com/men/181521.html
# test url https://sudsapda.com/top-lists/192650.html
# test urltest url  https://sudsapda.com/men/182631.htmltest url test url https://sudsapda.com/men/133315.html
# https://sudsapda.com/men/163332.html
#
# https://sudsapda.com/top-lists/118144.html
# test url https://sudsapda.com/men/152270.html
# test url https://sudsapda.com/top-lists/126981.html
# test urltest url  https://sudsapda.com/top-lists/122050.html
# test urltest urltest urlhttps://sudsapda.com/top-lists/150740.html
#  https://sudsapda.com/top-lists/131795.html
#  https://sudsapda.com/men/130865.htmltest url
# https://sudsapda.com/top-lists/130774.htmltest url https://sudsapda.com/top-lists/137231.html
#
#  test url https://sudsapda.com/top-lists/125835.html
# test urlhttps://sudsapda.com/men/170525.htmltest url https://sudsapda.com/top-lists/195485.html
#
# test urltest url https://sudsapda.com/top-lists/125327.html
# https://sudsapda.com/top-lists/149808.htmlhttps://sudsapda.com/top-lists/117193.html
#
# test url https://sudsapda.com/men/144689.html
# test url https://sudsapda.com/top-lists/152099.html
# test url test urlhttps://sudsapda.com/men/142543.htmltest url
#  https://sudsapda.com/top-lists/118234.html
# https://sudsapda.com/top-lists/146166.html
# test url test urltest urlhttps://sudsapda.com/top-lists/138333.html https://sudsapda.com/men/150152.html
#
# test url https://sudsapda.com/men/153117.html
# test url https://sudsapda.com/men/134186.html
# test url https://sudsapda.com/film/139675.html
# test url https://sudsapda.com/top-lists/112384.htmltest url
# https://sudsapda.com/top-lists/130598.html
# https://sudsapda.com/men/137300.html
# test url https://sudsapda.com/top-lists/116661.html
# test url https://sudsapda.com/top-lists/138890.html
# test urltest url https://sudsapda.com/top-lists/117657.html
# test url https://sudsapda.com/top-lists/122841.html
# https://sudsapda.com/film/137527.htmltest urltest url https://sudsapda.com/men/176666.html
#
# https://sudsapda.com/film/109360.html
# test url https://sudsapda.com/men/150222.htmltest url https://sudsapda.com/men/150616.html
#
# test url https://sudsapda.com/men/186293.html
# test url https://sudsapda.com/top-lists/138532.html
# test url https://sudsapda.com/men/140584.htmltest url
#  test urltest url  https://sudsapda.com/top-lists/112660.htmlhttps://sudsapda.com/men/156331.html
#
# https://sudsapda.com/men/139621.html
# test url https://sudsapda.com/top-lists/113090.html
# test url https://sudsapda.com/men/138827.html
# test url https://sudsapda.com/top-lists/124909.html
# test url https://sudsapda.com/men/185064.html
# test url https://sudsapda.com/men/142430.html
# test urltest url https://sudsapda.com/top-lists/116585.html
#  https://sudsapda.com/men/153594.html
# test url https://sudsapda.com/top-lists/149604.html
# test url https://sudsapda.com/top-lists/122880.html

# %%
# data.dataframe_web()

# %%
data.save_to_json()

# %%
# hey = data.dataframe_web()
# data.twitter_to_xlsx(hey)
