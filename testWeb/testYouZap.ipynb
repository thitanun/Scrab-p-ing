# %%
import re
import json
from urllib.parse import urlparse
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import pandas as pd

# %%
class testYouZap:

    def __init__(self):
        self.data = {}
        self.data['web'] = {}

    
    def remove_unuse_tag(self, bs : BeautifulSoup):
        unuse_tag = ['script', 'style ', 'noscript', 'head', 'footer', 'iframe']
        for tag in unuse_tag:
            for s in bs.select(tag):
                if s != None:
                    s.extract()
        return bs

    def clean_html(self, html : str):
        clean = re.compile('<.*?>')
        clean_text = re.sub(clean, '', html)
        for char in ['\n', '\t', '\r']:
            clean_text = clean_text.replace(char, '')
        clean_text = re.sub(' +', ' ', clean_text)
        return clean_text

    def data_in_link(self, session, url):
        self.list_url = []
        self.list_title = []
        self.list_content = []

        with session.get(url) as response:
            if not response.ok:
                return
            print('test url', url)
            
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs inlink', bs)
            
            self.data['web'][url] = {}
            self.data['web'][url]['title'] = bs.find('h1').text

            self.content = ''
            section = bs.find('div', {'class' : 'unselectable'})
            for p in section.find_all('p'):
                self.content += f'{self.clean_html(p.text)} ' #p.text
            self.data['web'][url]['content'] = self.content
            # print('test content inlink', self.content)



    def data_domain(self, session, url):
        with session.get(url) as response:
            if not response.ok:
                return
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs domain', bs)

            news_link = []
            for h2 in bs.find_all('h2', {'class' : 'post-title'}):
                a = h2.find('a')
                news_link.append(a.attrs['href'])
            # print('test news_link domain', news_link)

            n = len(news_link)
            # print('test n news_link domain', n)
            with ThreadPoolExecutor(max_workers=n) as executor:
                with requests.Session() as session:
                    executor.map(self.data_in_link, [session]*n, news_link)
                    executor.shutdown(wait=True)


    def scrap(self):
        pages_list = [f'https://kpop.youzab.com/page/{i}' for i in range(1, 11)]
        n = len(pages_list)
        # print('test page', pages_list)
        with ThreadPoolExecutor(max_workers=n) as executor:
            with requests.Session() as session:
                executor.map(self.data_domain, [session]*n, pages_list)
                executor.shutdown(wait=True)


    def save_to_json(self):
        with open(f'YouZap.json', 'w', encoding="UTF-8") as file:
            datafile = json.dumps(self.data, indent=4) 
            file.write(datafile)


    # def dataframe_web(self):

    #     data_web = [[self.list_url
    #                     ]]

    #     web_frame = pd.DataFrame(data=data_web,
    #                         columns=['link'])
    #     return web_frame

    # def twitter_to_xlsx(self, data):
    #     data.to_excel("hey_test.xlsx", engine="openpyxl", index=False)

# %%
data = testYouZap()
data

# %%
data.scrap()
# Out:
# test url https://kpop.youzab.com/146943
# test urltest url https://kpop.youzab.com/146936 https://kpop.youzab.com/146764
#
# test urltest url https://kpop.youzab.com/146933
#  https://kpop.youzab.com/146939
# test url test url https://kpop.youzab.com/146645
# https://kpop.youzab.com/146761
# test url https://kpop.youzab.com/147063
# test url https://kpop.youzab.com/146929
# test url https://kpop.youzab.com/146756
# test url https://kpop.youzab.com/147056
# test url https://kpop.youzab.com/146642
# test urltest url https://kpop.youzab.com/146750
#  https://kpop.youzab.com/146767
# test url https://kpop.youzab.com/146882
# test url https://kpop.youzab.com/147127
# test url https://kpop.youzab.com/146925
# test url https://kpop.youzab.com/146758
# test url https://kpop.youzab.com/147066
# test url https://kpop.youzab.com/146921
# test url https://kpop.youzab.com/146878
# test url https://kpop.youzab.com/146875
# test url https://kpop.youzab.com/146747
# test url https://kpop.youzab.com/146639
# test url https://kpop.youzab.com/146866
# test url https://kpop.youzab.com/146872
# test url https://kpop.youzab.com/146710
# test url https://kpop.youzab.com/146918
# test url https://kpop.youzab.com/146636
# test url https://kpop.youzab.com/147050
# test url https://kpop.youzab.com/147119
# test urltest url https://kpop.youzab.com/147047
#  https://kpop.youzab.com/147053
# test url https://kpop.youzab.com/147044
# test url https://kpop.youzab.com/146869
# test url https://kpop.youzab.com/146633
# test url https://kpop.youzab.com/146914
# test url https://kpop.youzab.com/146911
# test url https://kpop.youzab.com/146904
# test url https://kpop.youzab.com/146627
# test url https://kpop.youzab.com/147123
# test url https://kpop.youzab.com/146707
# test url https://kpop.youzab.com/146907
# test url https://kpop.youzab.com/146716
# test url https://kpop.youzab.com/146741
# test url https://kpop.youzab.com/146630
# test urltest url test urlhttps://kpop.youzab.com/147116 https://kpop.youzab.com/146705
#
#  https://kpop.youzab.com/147112
# test url https://kpop.youzab.com/147040
# test url https://kpop.youzab.com/146738
# test url https://kpop.youzab.com/146744
# test url https://kpop.youzab.com/146863
# test url https://kpop.youzab.com/146699
# test url https://kpop.youzab.com/146624
# test url https://kpop.youzab.com/146734
# test url https://kpop.youzab.com/146592
# test url https://kpop.youzab.com/146900
# test url https://kpop.youzab.com/146860
# test urltest url https://kpop.youzab.com/146894
#  https://kpop.youzab.com/146621
# test url https://kpop.youzab.com/146728
# test url https://kpop.youzab.com/146897
# test url https://kpop.youzab.com/146826
# test url https://kpop.youzab.com/146857
# test url https://kpop.youzab.com/147037
# test url https://kpop.youzab.com/147109
# test url https://kpop.youzab.com/147034
# test url https://kpop.youzab.com/147106
# test url https://kpop.youzab.com/146618
# test url https://kpop.youzab.com/146891
# test url https://kpop.youzab.com/146820
# test url https://kpop.youzab.com/146722
# test url https://kpop.youzab.com/146823
# test url https://kpop.youzab.com/147102
# test url https://kpop.youzab.com/147031
# test url https://kpop.youzab.com/146854
# test url https://kpop.youzab.com/146612
# test url https://kpop.youzab.com/147095
# test urltest url https://kpop.youzab.com/146725
#  https://kpop.youzab.com/146731
# test urltest url https://kpop.youzab.com/147098
#  https://kpop.youzab.com/146885
# test url https://kpop.youzab.com/146695
# test url https://kpop.youzab.com/146888
# test url https://kpop.youzab.com/146589
# test url https://kpop.youzab.com/146690
# test url https://kpop.youzab.com/147025
# test url https://kpop.youzab.com/146845
# test urltest url https://kpop.youzab.com/146851
#  https://kpop.youzab.com/146998
# test url https://kpop.youzab.com/146615
# test url https://kpop.youzab.com/146848
# test url https://kpop.youzab.com/146817
# test url https://kpop.youzab.com/147028
# test url https://kpop.youzab.com/146692
# test url https://kpop.youzab.com/146719
# test url https://kpop.youzab.com/147001
# test url https://kpop.youzab.com/146586
# test url https://kpop.youzab.com/146810
# test url https://kpop.youzab.com/146682
# test url https://kpop.youzab.com/146678
# test url https://kpop.youzab.com/146814
# test url https://kpop.youzab.com/146601
# test url https://kpop.youzab.com/146580
# test url https://kpop.youzab.com/147092
# test urltest url  https://kpop.youzab.com/146992
# https://kpop.youzab.com/147014test url https://kpop.youzab.com/146576
#
# test url https://kpop.youzab.com/146713
# test url https://kpop.youzab.com/146609
# test url https://kpop.youzab.com/146807
# test url https://kpop.youzab.com/146835
# test url https://kpop.youzab.com/146583test url
#  https://kpop.youzab.com/146838
# test url test urlhttps://kpop.youzab.com/146989 https://kpop.youzab.com/146605
# test urltest url https://kpop.youzab.com/147021
#
# test url  test urlhttps://kpop.youzab.com/146675https://kpop.youzab.com/146829
#  test url
#  https://kpop.youzab.com/146669https://kpop.youzab.com/146832
#
# test urltest url https://kpop.youzab.com/147011
#  https://kpop.youzab.com/146986
# test url test url https://kpop.youzab.com/146800https://kpop.youzab.com/146672
#
# test url https://kpop.youzab.com/147085
# test url https://kpop.youzab.com/147089
# test url https://kpop.youzab.com/146841
# test url https://kpop.youzab.com/147069
# test urltest url https://kpop.youzab.com/146567
# https://kpop.youzab.com/146797
# test url https://kpop.youzab.com/147073
# test urltest url https://kpop.youzab.com/147017
#  https://kpop.youzab.com/147082
# test url https://kpop.youzab.com/146560
# test url test url https://kpop.youzab.com/146659
# https://kpop.youzab.com/146595
# test url https://kpop.youzab.com/146804
# test url https://kpop.youzab.com/146598
# test url https://kpop.youzab.com/146666
# test url https://kpop.youzab.com/146563
# test urltest url  https://kpop.youzab.com/147076
# test urltest url https://kpop.youzab.com/146662
#  https://kpop.youzab.com/147079
# https://kpop.youzab.com/147006
# test url test urlhttps://kpop.youzab.com/146980 https://kpop.youzab.com/146573
#
# test url test urlhttps://kpop.youzab.com/146974test url https://kpop.youzab.com/146554
#  test url
# test url https://kpop.youzab.com/146995
# test urltest url test url https://kpop.youzab.com/146970test url https://kpop.youzab.com/146531 https://kpop.youzab.com/146781
# test urlhttps://kpop.youzab.com/146773
#
# test url test urlhttps://kpop.youzab.com/146541
#   https://kpop.youzab.com/146983
# https://kpop.youzab.com/146538test url
# https://kpop.youzab.com/146557
# test urltest urlhttps://kpop.youzab.com/146550test url https://kpop.youzab.com/146777
# https://kpop.youzab.com/146770
# test urltest url https://kpop.youzab.com/146967
#  https://kpop.youzab.com/146953
# test url https://kpop.youzab.com/146964test url
#  https://kpop.youzab.com/146547test urlhttps://kpop.youzab.com/146946
# https://kpop.youzab.com/146544
# test url
#   https://kpop.youzab.com/146794
# https://kpop.youzab.com/146652
# test url https://kpop.youzab.com/146791
#
# test url https://kpop.youzab.com/146977
# test url https://kpop.youzab.com/146788
#
# test url https://kpop.youzab.com/146949
# test url https://kpop.youzab.com/146534
# test url https://kpop.youzab.com/146649test url
# https://kpop.youzab.com/146956
# test url https://kpop.youzab.com/146962
# test url https://kpop.youzab.com/146655
# test url https://kpop.youzab.com/146784

# %%
# data.dataframe_web()

# %%
data.save_to_json()

# %%
# hey = data.dataframe_web()
# data.twitter_to_xlsx(hey)
