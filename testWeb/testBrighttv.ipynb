# %%
import re
import json
from urllib.parse import urlparse
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import pandas as pd

# %%
class testBrighttv:

    def __init__(self):
        self.data = {}
        self.data['web'] = {}

    
    def remove_unuse_tag(self, bs : BeautifulSoup):
        unuse_tag = ['script', 'style ', 'noscript', 'head', 'footer', 'iframe']
        for tag in unuse_tag:
            for s in bs.select(tag):
                if s != None:
                    s.extract()
        return bs

    def clean_html(self, html : str):
        clean = re.compile('<.*?>')
        clean_text = re.sub(clean, '', html)
        for char in ['\n', '\t', '\r']:
            clean_text = clean_text.replace(char, '')
        clean_text = re.sub(' +', ' ', clean_text)
        return clean_text

    def data_in_link(self, session, url):
        # self.list_url = []
        # self.list_title = []
        # self.list_content = []

        with session.get(url) as response:
            if not response.ok:
                return
            print('test url', url)
            
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs inlink', bs)
            
            self.data['web'][url] = {}
            self.data['web'][url]['title'] = bs.find('h1').text

            self.content = ''
            section = bs.find('main', {'id' : 'main'})
            # print('test sec', section)
            for p in section.find_all('p'):
                # print('test p', p)
                self.content += f'{self.clean_html(p.text)} ' #p.text
            self.data['web'][url]['content'] = self.content
            # print('test content inlink', self.content)



    def data_domain(self, session, url):
        with session.get(url) as response:
            # print('check re', response)
            if not response.ok:
                return
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs domain', bs)

            news_link = []
            for div in bs.find_all('h2', {'class' : 'entry-title'}):
                a = div.find('a')
                news_link.append(a.attrs['href'])
            # print('test news_link domain', news_link)

            n = len(news_link)
            # print('test n news_link domain', n)
            with ThreadPoolExecutor(max_workers=n) as executor:
                with requests.Session() as session:
                    executor.map(self.data_in_link, [session]*n, news_link)
                    executor.shutdown(wait=True)


    def scrap(self):
        pages_list = [f'https://www.brighttv.co.th/category/entertain/korea/page/{i}' for i in range(1, 11)]
        n = len(pages_list)
        print('test page' , pages_list)
        with ThreadPoolExecutor(max_workers=n) as executor:
            with requests.Session() as session:
                executor.map(self.data_domain, [session]*n, pages_list)
                executor.shutdown(wait=True)


    def save_to_json(self):
        with open(f'Brighttv.json', 'w', encoding="UTF-8") as file:
            datafile = json.dumps(self.data, indent=4) 
            file.write(datafile)


    # def dataframe_web(self):

    #     data_web = [[self.list_url
    #                     ]]

    #     web_frame = pd.DataFrame(data=data_web,
    #                         columns=['link'])
    #     return web_frame

    # def twitter_to_xlsx(self, data):
    #     data.to_excel("hey_test.xlsx", engine="openpyxl", index=False)

# %%
data = testBrighttv()
data

# %%
data.scrap()
# Out:
# test page ['https://www.brighttv.co.th/category/entertain/korea/page/1', 'https://www.brighttv.co.th/category/entertain/korea/page/2', 'https://www.brighttv.co.th/category/entertain/korea/page/3', 'https://www.brighttv.co.th/category/entertain/korea/page/4', 'https://www.brighttv.co.th/category/entertain/korea/page/5', 'https://www.brighttv.co.th/category/entertain/korea/page/6', 'https://www.brighttv.co.th/category/entertain/korea/page/7', 'https://www.brighttv.co.th/category/entertain/korea/page/8', 'https://www.brighttv.co.th/category/entertain/korea/page/9', 'https://www.brighttv.co.th/category/entertain/korea/page/10']
# test url https://www.brighttv.co.th/entertain/korea/gong-hyo-jin-kevin-oh
# test url test url https://www.brighttv.co.th/entertain/korea/bambam-wheels-up-itunes
# https://www.brighttv.co.th/entertain/korea/taeyeon-new-fashion-trend
# test url https://www.brighttv.co.th/entertain/korea/ive-cover-non-tanont
# test url https://www.brighttv.co.th/entertain/jennie-blackpink-hair
# test url https://www.brighttv.co.th/entertain/korea/korean-actors-military-uniforms
# test url https://www.brighttv.co.th/entertain/korea/bigbang-all-kill-still-life
# test url https://www.brighttv.co.th/entertain/korea/wendy-red-velvet-covid
# test url https://www.brighttv.co.th/entertain/dj-bookko-bambam
# test url https://www.brighttv.co.th/entertain/korea/sakura-louis-vuitton
# test url https://www.brighttv.co.th/entertain/korea/rose-blackpink-family
# test url test url https://www.brighttv.co.th/entertain/korea/dara-found-the-shoehttps://www.brighttv.co.th/entertain/korea/jin-bts-human-peach
#
# test url https://www.brighttv.co.th/entertain/welcome-bambam-thailand
# test url https://www.brighttv.co.th/entertain/korea/jennie-blackpink-party-us
# test url https://www.brighttv.co.th/entertain/korea/lisa-as-emoji
# test url https://www.brighttv.co.th/entertain/korea/rose-blackpink-tiffany-co-2
# test url https://www.brighttv.co.th/entertain/korea/bts-favorite-music-group-kca
# test urltest url  https://www.brighttv.co.th/entertain/korea/bts-island-in-the-seom
# https://www.brighttv.co.th/entertain/korea/boombayah-blackpink-youtubetest url https://www.brighttv.co.th/entertain/korea/lee-seunggi-lee-seyoung
#
# test url https://www.brighttv.co.th/entertain/bts-bigbang-seventeen
# test url https://www.brighttv.co.th/entertain/korea/brand-value-rankings-march
# test url https://www.brighttv.co.th/entertain/bambam-ghost-talk
# test url https://www.brighttv.co.th/entertain/korea/ive-leeseo-karina-picture
# test url https://www.brighttv.co.th/entertain/korea/vbts-lady-gaga
# test url https://www.brighttv.co.th/entertain/korea/ravi-leave-two-days-one-night
# test url https://www.brighttv.co.th/entertain/korea/lee-jung-hyun-welcome-child
# test url https://www.brighttv.co.th/entertain/korea/got7-may-comeback
# test urltest urltest url https://www.brighttv.co.th/entertain/korea/show-me-the-money-drug
#  https://www.brighttv.co.th/entertain/korea/sm-lay-relationship
# test url https://www.brighttv.co.th/entertain/korea/le-sserafim-pre-sales
# test url https://www.brighttv.co.th/entertain/korea/bts-v-jungkook-jin-protect
# test url https://www.brighttv.co.th/entertain/korea/hyunbin-sonyejin-photo-honeymoon
#  https://www.brighttv.co.th/entertain/korea/top5-wealthiest-korean-actorstest url https://www.brighttv.co.th/entertain/korea/jungkook-bts-best-dressed-grammy
#
# test url https://www.brighttv.co.th/entertain/korea/naeun-officially-leaves-apink
# test url https://www.brighttv.co.th/entertain/korea/bts-bruno-mars-anderson-paak
# test url https://www.brighttv.co.th/entertain/korea/seoyeji-luxury-visual-eve
# test url https://www.brighttv.co.th/entertain/korea/vbts-daily-life-us

# %%
# data.dataframe_web()

# %%
data.save_to_json()

# %%
# hey = data.dataframe_web()
# data.twitter_to_xlsx(hey)
