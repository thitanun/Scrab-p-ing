# %%
import re
import json
from urllib.parse import urlparse
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import pandas as pd

# %%
class testKbopping:

    def __init__(self):
        self.data = {}
        self.data['web'] = {}

    
    def remove_unuse_tag(self, bs : BeautifulSoup):
        unuse_tag = ['script', 'style ', 'noscript', 'head', 'footer', 'iframe']
        for tag in unuse_tag:
            for s in bs.select(tag):
                if s != None:
                    s.extract()
        return bs

    def clean_html(self, html : str):
        clean = re.compile('<.*?>')
        clean_text = re.sub(clean, '', html)
        for char in ['\n', '\t', '\r']:
            clean_text = clean_text.replace(char, '')
        clean_text = re.sub(' +', ' ', clean_text)
        return clean_text

    def data_in_link(self, session, url):
        self.list_url = []
        self.list_title = []
        self.list_content = []

        with session.get(url) as response:
            if not response.ok:
                return
            print('test url', url)
            
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs inlink', bs)
            
            self.data['web'][url] = {}
            self.data['web'][url]['title'] = bs.find('h1').text

            self.content = ''
            section = bs.find('div', {'class' : 'tdb-block-inner td-fix-index'})
            # print('test sec', section)
            for p in section.find_all('p'):
                # print('test p', p)
                self.content += f'{self.clean_html(p.text)} ' #p.text
            self.data['web'][url]['content'] = self.content
            # print('test content inlink', self.content)



    def data_domain(self, session, url):
        with session.get(url) as response:
            # print('check re', response)
            if not response.ok:
                return
            domain = urlparse(url).netloc
            bs = BeautifulSoup(response.text, 'html.parser')
            bs = self.remove_unuse_tag(bs)
            # print('test bs domain', bs)

            news_link = []
            for div in bs.find_all('div', {'class' : 'td-module-meta-info'}):
                a = div.find('a')
                news_link.append(a.attrs['href'])
            # print('test news_link domain', news_link)

            n = len(news_link)
            # print('test n news_link domain', n)
            with ThreadPoolExecutor(max_workers=n) as executor:
                with requests.Session() as session:
                    executor.map(self.data_in_link, [session]*n, news_link)
                    executor.shutdown(wait=True)


    def scrap(self):
        pages_list = [f'https://kbopping.com/page/{i}/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB' for i in range(1, 11)]
        n = len(pages_list)
        print('test page' , pages_list)
        with ThreadPoolExecutor(max_workers=n) as executor:
            with requests.Session() as session:
                executor.map(self.data_domain, [session]*n, pages_list)
                executor.shutdown(wait=True)


    def save_to_json(self):
        with open(f'Kbopping.json', 'w', encoding="UTF-8") as file:
            datafile = json.dumps(self.data, indent=4) 
            file.write(datafile)


    # def dataframe_web(self):

    #     data_web = [[self.list_url
    #                     ]]

    #     web_frame = pd.DataFrame(data=data_web,
    #                         columns=['link'])
    #     return web_frame

    # def twitter_to_xlsx(self, data):
    #     data.to_excel("hey_test.xlsx", engine="openpyxl", index=False)

# %%
data = testKbopping()
data

# %%
data.scrap()
# Out:
# test page ['https://kbopping.com/page/1/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/2/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/3/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/4/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/5/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/6/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/7/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/8/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/9/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB', 'https://kbopping.com/page/10/?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fI2SwocoP65-mBcb_wvgpa8bfOW3Bpd-fziFR7dBovFAYkgXcXOQcsaAsp2EALw_wcB']
# test url https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test url https://kbopping.com/blackpink/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/bigbangs-daesung-wins-1st-place-on-m-countdown-its-an-honor-to-be-recorded-together-in-your-past-and-present/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/blackpink/test url https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
#
# test url https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/seventeen-4th-regular-album-release-on-may-27th/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/blackpink/
# test url https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/bts/
# test urltest url  https://kbopping.com/blackpink/
# https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test url https://kbopping.com/bts/
# test urltest url  https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/bts-my-universe-tops-us-billboard-chart-for-29th-week/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test url https://kbopping.com/blackpink/
# test url https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test url https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/test urltest url
#   https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
# https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test url https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# test url https://kbopping.com/bts/
# test url https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test url https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
# test url https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test url https://kbopping.com/purple-kiss-pretty-psycho-performance-video-released/
# test urltest url https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
#  https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-21/
# test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test urltest url https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
#  https://kbopping.com/departure-on-the-20th-for-the-coachella-performance-aespa-writes-a-new-history/
# test url test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
# test urltest url https://kbopping.com/mcnd-unveiled-juice-on-the-european-tour-stage-swag-exploded/ https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test urltest url https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-19/
#  https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# test url test url https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test url https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# test urltest url  https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test urltest url https://kbopping.com/blackpink/
#  https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
# test url https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test url https://kbopping.com/blackpink/
# test url https://kbopping.com/bts-14th-week-of-billboards-hot-100-top-10/
# test urltest url https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-23/
#  https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/test url
#  https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
#
# test url test url https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-20/
# https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-22/test url
#  https://kbopping.com/ive-entered-the-top-10-on-billboards-global-chart/
# test url https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-11/
# test url test urlhttps://kbopping.com/k-pop-daily-chart-apple-music-2022-04-24/
# test url test urlhttps://kbopping.com/k-pop-daily-chart-apple-music-2022-04-18/
#  https://kbopping.com/blackpink/
# test url test urlhttps://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/ https://kbopping.com/pre-orders-for-tomorrow-x-togethers-4th-mini-album-exceeded-816000/
#  https://kbopping.com/k-pop-weekly-chart-billboard-2022-04-17/
# test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test url https://kbopping.com/bts/
# test url
#  https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# test urltest urltest url https://kbopping.com/dreamcatcher-is-promoting-apocalypse-save-us-in-the-first-week/test url  https://kbopping.com/35th-golden-blackpink%c2%b7itzy%c2%b7twice%c2%b7red-velvet-ireneseulgi%c2%b7mamamoo%c2%b7iu/
# https://kbopping.com/psy-reveals-additional-information-on-3-songs-from-the-9th-regular-album-giriboy-crush-sung-sikyung-and-heize-support/
#
# https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test urltest url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
#  https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-17/
# test urltest url  test url https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-13/https://kbopping.com/blackpink/
# https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-10/
#
# test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test urltest url https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
# test url https://kbopping.com/blackpink-lisas-new-pictorial-elle/test url
#  https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-12/
# test url https://kbopping.com/k-pop-weekly-chart-youtube-2022-04-15/
# test url https://kbopping.com/k-pop-weekly-chart-youtube-2022-04-08/
#  test url https://kbopping.com/k-pop-weekly-chart-billboard-2022-04-10/
# https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
# test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test url https://kbopping.com/monsta-x-the-ultimate-visual/
# test url https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
# test url test urlhttps://kbopping.com/k-pop-daily-chart-apple-music-2022-04-15/
#  test urltest url https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test url https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-16/
# test url https://kbopping.com/blackpink/
#
# https://kbopping.com/k-pop-weekly-chart-youtube-2022-04-01/
#  https://kbopping.com/k-pop-daily-chart-apple-music-2022-04-14/test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
#
# test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test urltest url  https://kbopping.com/loona-queendom-2-ambush/
# https://kbopping.com/tomorrow-x-together-with-their-4th-mini-album-4th-generation-leader/
# test urltest urltest url test url test url test urlhttps://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/test url https://kbopping.com/bts-jungkook-instagrams-2-days-in-a-row-daily-follower-increase-1st-place-social-king/
# test url https://kbopping.com/my-gi-dle-miyeon-first-solo-album-scheduler-released/https://kbopping.com/everglow-releases-pirate-remix-sound-source-with-dj-r3hab/
#   https://kbopping.com/queendom-2-wjsn-turns-crisis-into-opportunity-navillera-unrivaled-performance-praise/
#
# test urlhttps://kbopping.com/twenty-five-twenty-one-wjsn-bona-ranked-2nd-in-april-girl-group-personal-brand-reputation-will-it-even-surpass-no-1-jennie/https://kbopping.com/purple-kiss-memem-performance-video/
# test url
#
# test url https://kbopping.com/god-the-beat-step-back-mv-hits-100-million-views/
#  https://kbopping.com/boa-releases-the-4th-song-do-the-motion-of-self-cover-project-in-japan-on-the-11th/ test urltest urlhttps://kbopping.com/purple-kiss-memem-performance-video/
#
# test urltest urltest url test urlhttps://kbopping.com/purple-kiss-memem-performance-video/test url https://kbopping.com/ateez-japanese-2nd-mini-album-release-on-may-25th/
#
#  https://kbopping.com/seventeen-releases-their-first-english-single-darling/https://kbopping.com/purple-kiss-memem-performance-video/  https://kbopping.com/bts-came-back-on-the-19th-start-preparing-for-a-new-album/
#
#
# https://kbopping.com/treasure-darari-performance-video-with-challenge-movements/test urltest url test url https://kbopping.com/heeseung-the-fourth-runner-of-enhypen-en-log-buy-a-suit-%e2%86%92-visit-a-dog-cafe-sharing-small-daily-life/
# https://kbopping.com/enhypen-ni-ki-reveals-small-daily-life-with-jay-and-jungwon-global-fan-communication/https://kbopping.com/bts-transforms-las-vegas-into-borahaegas/
# https://kbopping.com/announcement-of-comeback-on-may-3-ikons-flashback/test url https://kbopping.com/2020-tma-super-juniors-new-song-stage-first-released-%e2%86%92-hee-cheol-kim-joined/
# test urlhttps://kbopping.com/ive-1st-place-on-the-show-love-dive/
#
#  https://kbopping.com/april-girl-group-brand-reputation-1st-gi-dle-2nd-blackpink-3rd-red-velvet-korea-corporate-reputation-research-institute/
#
# test url https://kbopping.com/eun-bi-kwon-glitch-mv-surpasses-10-million-views-global-popularity/
# test url https://kbopping.com/bigbang-sweeps-the-charts-for-the-6th-day/
#
# test url test url https://kbopping.com/seventeen-mtv-fresh-out-live-in-the-us/
# https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
# test url https://kbopping.com/seventeens-visual-is-fantastic-darling-concept-photos-released/
# test url https://kbopping.com/purple-kiss-memem-performance-video/
# test url https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
# test urltest urltest url https://kbopping.com/purple-kiss-memem-performance-video/
# test url https://kbopping.com/the-shortest-record-in-instagram-history-bts-v-surpasses-40-million-followers/
#   https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/test urlhttps://kbopping.com/shinee-onew-adds-diversity-to-its-unique-tone/ https://kbopping.com/tnx-releases-teaser-video-ahead-of-its-debut/
#
#
# test urltest url https://kbopping.com/inkigayo-bigbang-start-hunting-for-the-1st-place-trophy-shinee-onew-and-jessie-comeback/
# test url https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
# test url https://kbopping.com/epik-high-ends-long-north-american-tour-global-popularity-even-to-coachella-in-the-us/
# test url https://kbopping.com/ravi-to-hold-a-solo-concert-on-the-7th-and-8th-of-next-month/test urltest url https://kbopping.com/ikon-to-hold-its-first-online-fan-meetup-meet-fans-all-over-the-world/
#
#  https://kbopping.com/bts-v-we-failed-to-win-the-grammy-it-was-neat-admit/
# test url https://kbopping.com/le-sserafim-sakura-the-gorgeous-goddess-of-spring/
# test url https://kbopping.com/comeback-on-may-3-ikon-the-title-song-is-but-you/test url
# test urltest url test url https://kbopping.com/2ne1-is-back-in-7-years-coachella/
#  https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
#  test urltest urltest url https://kbopping.com/blackpink-comeback-jennies-new-hairstyle-raises-fans-expectation/
# test url test url test url https://kbopping.com/purple-kiss-memem-performance-video/
# https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
# https://kbopping.com/seventeens-darling-global-popularity-expands-to-apple-stores-in-the-us/
# test url https://kbopping.com/exos-10th-anniversary-fan-event-has-been-completed-we-are-all-happy-to-celebrate-our-10th-anniversary-together/
# test urlhttps://kbopping.com/monsta-x-releases-shape-of-love-on-the-26th/
# https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/ https://kbopping.com/treasures-first-concert-full-of-joy-and-tears/
# test url https://kbopping.com/purple-kiss-memem-performance-video/test url https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
# test url https://kbopping.com/viviz-to-perform-for-grammys-global-spin-digital-series/
#
#  https://kbopping.com/seventeen-its-spring/
# https://kbopping.com/exos-10th-anniversary-of-debut-with-fans/
# test urltest url https://kbopping.com/winner-ikon-treasure-bigbangs-still-life-spring-summer-fall-winter-reaction/
#  test urltest url https://kbopping.com/hybes-first-girl-group-le-sserafim-unveils-a-six-member-group-with-bold-charm/test urltest url test url https://kbopping.com/gi-dles-miyeon-new-song-my-romantic-mood-concept-photo-released/
# https://kbopping.com/ive-top-5-in-initial-sales-among-girl-groups-only-4-months-since-their-debut/
#
# https://kbopping.com/btss-boy-with-luv-feat-halsey-surpassed-1-5-billion-views/https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/test urltest urltest url
#  https://kbopping.com/psy-will-his-concert-resume/test url https://kbopping.com/nmixx-o-o-mv-60-million-views-moving-forward-towards-100-million-views/
#  https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/test url https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test url https://kbopping.com/super-rookie-kepler-debut-song-wa-da-da-mv-surpasses-100-million-views/
# test url https://kbopping.com/le-sserafim-releases-debut-trailer/
# https://kbopping.com/kpop-social-media-trends-on-04-15-2022-ives-love-dive-and-just-bs-reload/
#  https://kbopping.com/sistars-shake-it-perfectly-reinterpreted-in-queendom-2-loona-proves-performance-master/
# test url
#  https://kbopping.com/ive-overtook-bigbang-to-take-the-top-spot-on-music-bank-i-love-you-dive/
#
#
#
# test urltest url  https://kbopping.com/purple-kiss-memem-performance-video/https://kbopping.com/bigbang-loved-by-people-of-all-ages/
#
# test url https://kbopping.com/nct-dream-glitch-mode-1st-in-united-world-chart/
# test url test urlhttps://kbopping.com/le-sserafims-fearless-show-unveiled-a-strong-first-step/test url  https://kbopping.com/bts-in-las-audition-applicants-dreaming-of-the-next-bts/
# https://kbopping.com/high-school-rapper-4-seung-hoon-lee-is-the-final-winner/
# test url test urlhttps://kbopping.com/aespa-the-worlds-splendid-fashion/ https://kbopping.com/sunmi-exuding-an-aura-from-the-sidewalk-block/
#
# test url
#  https://kbopping.com/apple-tim-cook-looking-forward-to-seventeen-x-apple-collaboration-we-are-thrilled-to-have-you/test url
# test urltest url  https://kbopping.com/stray-kids-of-course-performance-mastermind/test url https://kbopping.com/purple-kiss-memem-performance-video/
#
# https://kbopping.com/just-b-comeback-with-just-begun/
# https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/
# test url https://kbopping.com/kpop-social-media-trends-on-02-16-2022-treasures-jikjin-and-apinks-dilemma/
#  https://kbopping.com/ikon-to-make-a-full-comeback-after-1-year-coming-soon-poster-surprise-release/
# test url https://kbopping.com/psy-releases-teaser-for-9th-album-everyday-that-shows-enthusiasm-for-drenched-show/
# test url https://kbopping.com/expectations-for-tomorrow-x-togethers-comeback%e2%86%91-spoiler-week/
# test url https://kbopping.com/psy-showterview-scramble-ahead-of-comeback-prediction-of-special-chemistry-with-jessi/
# test url https://kbopping.com/purple-kiss-memem-performance-video/
# test url https://kbopping.com/after-school-nana-a-dizzying-pose-%e2%86%92-kahi-is-also-surprised-oh-huh/

# %%
# data.dataframe_web()

# %%
data.save_to_json()

# %%
# hey = data.dataframe_web()
# data.twitter_to_xlsx(hey)
