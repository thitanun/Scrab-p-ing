# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import logging
from urllib.parse import urljoin
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from textblob import TextBlob
import csv
import re

# %%
class ClawWeb:
    def __init__(self, url:str):
        r = requests.get(url)
        self.soup = BeautifulSoup(r.text, "html.parser")
        self.link = self.get_link()
        self.head = self.get_head()
        self.body = self.get_body()
        # self.content = self.get_content()
        self.save = self.get_save()
        # self.senti = self.sentiment()

    def get_link(self):
        issue = self.soup.find_all('a', href = True, attrs = {'class' : 'qa-heading-link lx-stream-post__header-link'})
        self.list_link = []
        for i in issue:
            if "https://www.bbc.com" in i['href']:
                self.list_link.append(i['href'])
            else:
                self.list_link.append("https://www.bbc.com"+i['href'])
        return self.list_link

    def get_head(self):
        issue = self.soup.find_all('a', href = True, attrs = {'class' : 'qa-heading-link lx-stream-post__header-link'})
        list_head = []
        for i in issue:
            # print('test', i.string)
            if i.string == None:
                pass
            else:
                if i.string not in list_head:
                    list_head.append(i.string)
        return list_head

    def get_body(self):
        issue = self.soup.find_all('p', {'class' : 'lx-stream-related-story--summary qa-story-summary'})
        list_body = []
        for i in issue:
            if i.string == None:
                pass
            else:
                if i.string not in list_body:
                    list_body.append(i.string)
        return list_body

    
    # def get_content(self):
    #     issue = self.soup.find_all('p', {'class' : 'ssrcss-1q0x1qg-Paragraph eq5iqo00'})

    #     list_content = []
    #     for k in issue:
    #         print('test', k)
    #         if k.string == None:
    #             list_content.append("nan")
    #         else:
    #             # print(k.string)
    #             list_content.append(k.string)
    #     return list_content

    
    def sentiment(self, text_en):
        sentiment_text = text_en.sentiment.polarity
        if  sentiment_text > 0:
            return 'positive'
        elif sentiment_text < 0:
            return 'negative'
        else:
            return 'neutral'

    def list_to_text(self ,txt):
        new_head = []
        for i in txt:
            # print("i",i)     
            new_head.append(self.sentiment(TextBlob(i)))
        return new_head


    def get_save(self):
        table = {"head" : self.head, "sentiment" : self.list_to_text(self.head), "link" : self.link}
        df = pd.DataFrame(data = table)
        df.to_excel('testweb.xlsx', index=False)
        return df

# %%
# l = ClawWeb("https://www.bbc.com/news/world-60525350")
l = ClawWeb("https://www.bbc.com/news/entertainment_and_arts")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
l.head
# Out:
# ['Town poised for week of night time culture',
#  'Why is steroid use rising among male bodybuilders?',
#  'Boys record charity cover of Let It Be for Ukraine',
#  "Woman's dwarfism ignorance fight starts in schools",
#  'Irish dancers excited to be back on the big stage',
#  'Eagle Has Landed author dies aged 92',
#  'Hijab-wearing Indian teen rapper breaks stereotypes',
#  'Artist paints mural trail inspired by Van Gogh',
#  'Brian Cox: Succession role makes me swear more',
#  'Artist captures Antarctic on polar trip',
#  'Thrones under the hammer: From loo to tiny theatre',
#  "Inside London's only pointe shoes factory",
#  'The school that helped Ukrainian musicians find safety',
#  'Will Smith banned from Oscars for 10 years',
#  'Collection changes name to promote women artists',
#  'Harry Styles unseats Dave at the top of the charts',
#  'Peacock mural displays LGBT+ pride in team',
#  'Cinema donated to community to use as theatre',
#  'Richard Osman quits BBC quiz show Pointless',
#  'Pink Floyd reunite for Ukraine protest song']

# %%
l.link
# Out:
# ['https://www.bbc.com/news/uk-england-beds-bucks-herts-61031116',
#  'https://www.bbc.com/news/uk-england-gloucestershire-60765050',
#  'https://www.bbc.com/news/uk-england-birmingham-61042355',
#  'https://www.bbc.com/news/uk-wales-61037196',
#  'https://www.bbc.com/news/uk-northern-ireland-61025398',
#  'https://www.bbc.com/news/entertainment-arts-61054455',
#  'https://www.bbc.com/news/world-asia-india-61015974',
#  'https://www.bbc.com/news/uk-england-bristol-61029857',
#  'https://www.bbc.com/news/uk-scotland-61014190',
#  'https://www.bbc.com/news/uk-england-suffolk-61024178',
#  'https://www.bbc.com/news/uk-wales-60920228',
#  'https://www.bbc.com/news/uk-england-london-61011231',
#  'https://www.bbc.com/news/world-europe-61038463',
#  'https://www.bbc.com/news/world-us-canada-61018821',
#  'https://www.bbc.com/news/uk-england-cambridgeshire-61045337',
#  'https://www.bbc.com/news/entertainment-arts-61043741',
#  'https://www.bbc.com/news/uk-england-leeds-61040828',
#  'https://www.bbc.com/news/uk-england-devon-61040866',
#  'https://www.bbc.com/news/entertainment-arts-61037388',
#  'https://www.bbc.com/news/entertainment-arts-61037080']

# %%
l.body
# Out:
# ['About US, a free open air event, will be staged in the centre of Luton from 14 to 20 April.',
#  'More bodybuilders are taking drugs knowing the damage they can do to their bodies, an academic says.',
#  "Wolverhampton schoolboys Jacob and Oliver adapted The Beatles' lyrics for their charity song.",
#  'Danielle endures frequent name-calling, stares and people trying to take photos of her.',
#  'Belfast hosts the first World Irish Dancing Championships after two years of Covid cancellations.',
#  'Henry Patterson wrote 85 novels, including the WW2 thriller penned under the pseudonym Jack Higgins.',
#  "Farrah Fortnam created the trail to coincide with an immersive exhibition of the famous artist's work.",
#  "The 75-year-old Scottish actor says he seems to be possessed by TV character Logan Roy's bad language.",
#  "Claudia Myatt's voyage with the Royal Navy sees her fill her sketchbooks with wildlife and more.",
#  'Why one art lover spent £70,000 on a public toilet transformation that was far from bog standard.',
#  'The Academy voted on Friday to sanction Smith after he slapped Chris Rock at the awards show.',
#  'A Cambridge college says the percentage of works by women in public galleries is shamefully low.',
#  "Styles' new single, As It Was, debuts at number one with the biggest first-week sales of the year.",
#  'The Peacock mural on a building adjoining York Road will be seen by thousands passing on the A64(M).',
#  'Central Cinema has been purchased by an anonymous benefactor and gifted to a local theatre company.',
#  'The co-host has appeared on the show since 2009, but is leaving to focus on his writing.',
#  'The band\'s first new material in 28 years was inspired by David Gilmour\'s "anger" over the war.']

# %%
print(l.link[0])
print(l.head[0])
# Out:
# https://www.bbc.com/news/uk-england-beds-bucks-herts-61031116
# Town poised for week of night time culture

# %%
l.save
# Out:
#                                                  head sentiment  \
# 0          Town poised for week of night time culture   neutral
# 1   Why is steroid use rising among male bodybuild...   neutral
# 2   Boys record charity cover of Let It Be for Ukr...   neutral
# 3   Woman's dwarfism ignorance fight starts in sch...   neutral
# 4   Irish dancers excited to be back on the big stage  positive
# 5                Eagle Has Landed author dies aged 92  negative
# 6   Hijab-wearing Indian teen rapper breaks stereo...   neutral
# 7      Artist paints mural trail inspired by Van Gogh   neutral
# 8      Brian Cox: Succession role makes me swear more  positive
# 9             Artist captures Antarctic on polar trip  negative
# 10  Thrones under the hammer: From loo to tiny the...   neutral
# 11          Inside London's only pointe shoes factory   neutral
# 12  The school that helped Ukrainian musicians fin...   neutral
# 13         Will Smith banned from Oscars for 10 years   neutral
# 14   Collection changes name to promote women artists   neutral
# 15  Harry Styles unseats Dave at the top of the ch...  positive
# 16         Peacock mural displays LGBT+ pride in team   neutral
# 17      Cinema donated to community to use as theatre   neutral
# 18        Richard Osman quits BBC quiz show Pointless  negative
# 19        Pink Floyd reunite for Ukraine protest song  negative
#
#                                                  link
# 0   https://www.bbc.com/news/uk-england-beds-bucks...
# 1   https://www.bbc.com/news/uk-england-gloucester...
# 2   https://www.bbc.com/news/uk-england-birmingham...
# 3          https://www.bbc.com/news/uk-wales-61037196
# 4   https://www.bbc.com/news/uk-northern-ireland-6...
# 5   https://www.bbc.com/news/entertainment-arts-61...
# 6   https://www.bbc.com/news/world-asia-india-6101...
# 7   https://www.bbc.com/news/uk-england-bristol-61...
# 8       https://www.bbc.com/news/uk-scotland-61014190
# 9   https://www.bbc.com/news/uk-england-suffolk-61...
# 10         https://www.bbc.com/news/uk-wales-60920228
# 11  https://www.bbc.com/news/uk-england-london-610...
# 12     https://www.bbc.com/news/world-europe-61038463
# 13  https://www.bbc.com/news/world-us-canada-61018821
# 14  https://www.bbc.com/news/uk-england-cambridges...
# 15  https://www.bbc.com/news/entertainment-arts-61...
# 16  https://www.bbc.com/news/uk-england-leeds-6104...
# 17  https://www.bbc.com/news/uk-england-devon-6104...
# 18  https://www.bbc.com/news/entertainment-arts-61...
# 19  https://www.bbc.com/news/entertainment-arts-61...

# %%
def get_content(url:str):
    print('url', url)
    print("\n")
    re = requests.get(url)
    soup = BeautifulSoup(re.text, "html.parser")
    issue = soup.find_all('p', {'class' : 'ssrcss-1q0x1qg-Paragraph eq5iqo00'})

    list_content = []
    for k in issue:
        if k.string == None:
            pass
        else:
            print(k.string)
            list_content.append(k.string)
    return(list_content)

# def pd_con(a):
#     print('hey', a)
#     table = {"content" : a, "sentiment" : ClawWeb.sentiment(TextBlob(ClawWeb.list_to_text(a)))}
#     df = pd.DataFrame(data = table)
#     return df

# %%
get_content(l.link[0])
# Out:
# url https://www.bbc.com/news/uk-england-beds-bucks-herts-61031116
#
#
# Luton town centre is poised to host a week-long night time culture which will include music, light shows and performances.
# Julia Horseman, from Luton Business Improvement District (BID), said: "It's thrilling to be welcoming such a unique outdoor multimedia display right into the heart of our town centre."
# New music created for the event will be performed by choirs from the town.
# Showtime will start at 20:30 BST and will celebrate the entire history of the universe from the Big Bang to the present day and is part of UNBOXED: Creativity in the UK, organisers said.
# It will feature live shows by artists who worked on the London 2012 Olympic Games' opening ceremony.
# Gail Windrass, from the town, will be performing specially created music by Nitin Sawhney CBE, with her choir, Big Music Company.
# "Luton sometimes doesn't get the publicity it deserves, she said.
# "I think everyone wants us to be like London, but having this vibrant hub of culture that is so professional and cutting edge - I think it will make people really excited and hopefully more things like this will come to Luton."
# "From what we have seen and heard already, it really will be a spectacular event.
# "We're expecting lots of extra people to flock to the area to enjoy the display, performances, music and projections over the week, and we can't wait for the buzz it will bring for workers, shoppers, visitors and residents."
# What did Putin do before he came to power?
# Robert Plant on how he felt about fronting Led Zeppelin
# There's something for everyone on BBC iPlayer
# ['Luton town centre is poised to host a week-long night time culture which will include music, light shows and performances.',
#  'Julia Horseman, from Luton Business Improvement District (BID), said: "It\'s thrilling to be welcoming such a unique outdoor multimedia display right into the heart of our town centre."',
#  'New music created for the event will be performed by choirs from the town.',
#  'Showtime will start at 20:30 BST and will celebrate the entire history of the universe from the Big Bang to the present day and is part of UNBOXED: Creativity in the UK, organisers said. ',
#  "It will feature live shows by artists who worked on the London 2012 Olympic Games' opening ceremony. ",
#  'Gail Windrass, from the town, will be performing specially created music by Nitin Sawhney CBE, with her choir, Big Music Company. ',
#  '"Luton sometimes doesn\'t get the publicity it deserves, she said.',
#  '"I think everyone wants us to be like London, but having this vibrant hub of culture that is so professional and cutting edge - I think it will make people really excited and hopefully more things like this will come to Luton."',
#  '"From what we have seen and heard already, it really will be a spectacular event.',
#  '"We\'re expecting lots of extra people to flock to the area to enjoy the display, performances, music and projections over the week, and we can\'t wait for the buzz it will bring for workers, shoppers, visitors and residents."',
#  'What did Putin do before he came to power?',
#  'Robert Plant on how he felt about fronting Led Zeppelin',
#  "There's something for everyone on BBC iPlayer"]

# %%
# pd_con(get_content(l.link[0]))
